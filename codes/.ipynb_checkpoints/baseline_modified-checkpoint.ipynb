# %% [markdown]
# ## 목차
# ### 1. Library Import
# ### 2. 학습데이터 생성
# ### 3. Light-gbm 모델 훈련
# ### 4. 교차 검증 점수 확인
# ### 5. 제출 파일 생성

# %% [markdown]
# # 1. Library Import

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc #garbage collection 감시
import random
import lightgbm as lgb
import re
from sklearn.metrics import *
from sklearn.model_selection import KFold
import warnings
import seaborn as sns
warnings.filterwarnings(action='ignore')

# 필요한 함수 정의
def make_datetime(x):
    # string 타입의 Time column을 datetime 타입으로 변경
    x     = str(x)
    year  = int(x[:4])
    month = int(x[4:6])
    day   = int(x[6:8])
    hour  = int(x[8:10])
    min  = int(x[10:12])
    sec  = int(x[12:])
    return dt.datetime(year, month, day, hour)

def string2num(x):
    # (,)( )과 같은 불필요한 데이터 정제
    x = re.sub(r"[^0-9]+", '', str(x))
    if x =='':
        return 0
    else:
        return int(x)


PATH = '/content/drive/MyDrive/YBIGTA/21-1 겨울방학/lg 품질변화 공모전/quality_change_prediction/data/'

# %% [markdown]
# # 3. Light-gbm 모델 훈련

# %%
# 변수 이름 변경
# error  -> train_x
# problem-> train_y
train = pd.read_csv("data/0201_train.csv")
test = pd.read_csv("data/0201_test.csv")
train_x = train.drop(columns=["Unnamed: 0","user_id","label"])
train_y = train["label"]
test_x = test.drop(columns=["Unnamed: 0","user_id"])


print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 61)
# (15000,)

# %%
# Train
#-------------------------------------------------------------------------------------
# validation auc score를 확인하기 위해 정의
def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'boosting_type' : 'dart',
                'objective'     : 'cross_entropy',
                'metric'        : 'auc',
                "learning_rate" : 0.007,
                'seed': 234,
                "xgboost_dart_mode": True,
    "linear_tree": True,
    "min_data_in_leaf": 10
                }
#-------------------------------------------------------------------------------------
# 5 Kfold cross validation
k_fold = KFold(n_splits=5, shuffle=True, random_state=42)
for train_idx, val_idx in k_fold.split(train_x):

    # split train, validation set
    X = train_x.iloc[train_idx,:]
    y = train_y[train_idx]
    valid_x = train_x.iloc[val_idx,:]
    valid_y = train_y[val_idx]

    d_train= lgb.Dataset(X, y)
    d_val  = lgb.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgb.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 2000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 3
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002475 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8294
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 61
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.302750 -> initscore = -0.834237
# [LightGBM] [Info] Start training from score -0.834237
# [20]	valid_0's auc: 0.79024	valid_0's pr_auc: 0.796019
# [40]	valid_0's auc: 0.794663	valid_0's pr_auc: 0.800061
# [60]	valid_0's auc: 0.798625	valid_0's pr_auc: 0.802555
# [80]	valid_0's auc: 0.799326	valid_0's pr_auc: 0.801028
# [100]	valid_0's auc: 0.800152	valid_0's pr_auc: 0.801653
# [120]	valid_0's auc: 0.801291	valid_0's pr_auc: 0.801802
# [140]	valid_0's auc: 0.803843	valid_0's pr_auc: 0.806334
# [160]	valid_0's auc: 0.80512	valid_0's pr_auc: 0.807408
# [180]	valid_0's auc: 0.806738	valid_0's pr_auc: 0.808976
# [200]	valid_0's auc: 0.808214	valid_0's pr_auc: 0.81005
# [220]	valid_0's auc: 0.809862	valid_0's pr_auc: 0.810936
# [240]	valid_0's auc: 0.810618	valid_0's pr_auc: 0.811107
# [260]	valid_0's auc: 0.811253	valid_0's pr_auc: 0.811712
# [280]	valid_0's auc: 0.812062	valid_0's pr_auc: 0.811785
# [300]	valid_0's auc: 0.813293	valid_0's pr_auc: 0.81262
# [320]	valid_0's auc: 0.813769	valid_0's pr_auc: 0.812854
# [340]	valid_0's auc: 0.814778	valid_0's pr_auc: 0.813633
# [360]	valid_0's auc: 0.815022	valid_0's pr_auc: 0.813742
# [380]	valid_0's auc: 0.815099	valid_0's pr_auc: 0.81363
# [400]	valid_0's auc: 0.815317	valid_0's pr_auc: 0.814593
# [420]	valid_0's auc: 0.81562	valid_0's pr_auc: 0.814875
# [440]	valid_0's auc: 0.815926	valid_0's pr_auc: 0.814775
# [460]	valid_0's auc: 0.816463	valid_0's pr_auc: 0.815226
# [480]	valid_0's auc: 0.817088	valid_0's pr_auc: 0.815604
# [500]	valid_0's auc: 0.817366	valid_0's pr_auc: 0.816527
# [520]	valid_0's auc: 0.817632	valid_0's pr_auc: 0.817082
# [540]	valid_0's auc: 0.817965	valid_0's pr_auc: 0.817605
# [560]	valid_0's auc: 0.81834	valid_0's pr_auc: 0.818129
# [580]	valid_0's auc: 0.818527	valid_0's pr_auc: 0.818159
# [600]	valid_0's auc: 0.818634	valid_0's pr_auc: 0.818146
# [620]	valid_0's auc: 0.818816	valid_0's pr_auc: 0.818222
# [640]	valid_0's auc: 0.819136	valid_0's pr_auc: 0.818371
# [660]	valid_0's auc: 0.8192	valid_0's pr_auc: 0.81807
# [680]	valid_0's auc: 0.819233	valid_0's pr_auc: 0.817943
# [1520]	valid_0's auc: 0.82292	valid_0's pr_auc: 0.82346
# [1540]	valid_0's auc: 0.822936	valid_0's pr_auc: 0.82349
# [1560]	valid_0's auc: 0.822963	valid_0's pr_auc: 0.823441
# [1580]	valid_0's auc: 0.823011	valid_0's pr_auc: 0.823444
# [1600]	valid_0's auc: 0.823091	valid_0's pr_auc: 0.823421
# [1620]	valid_0's auc: 0.823117	valid_0's pr_auc: 0.823457
# [1640]	valid_0's auc: 0.823154	valid_0's pr_auc: 0.823342
# [1660]	valid_0's auc: 0.823192	valid_0's pr_auc: 0.82332
# [1680]	valid_0's auc: 0.823138	valid_0's pr_auc: 0.823295
# [1700]	valid_0's auc: 0.823145	valid_0's pr_auc: 0.823331
# [1720]	valid_0's auc: 0.823075	valid_0's pr_auc: 0.823324
# [1740]	valid_0's auc: 0.82311	valid_0's pr_auc: 0.823218
# [1760]	valid_0's auc: 0.823152	valid_0's pr_auc: 0.82324
# [1780]	valid_0's auc: 0.82318	valid_0's pr_auc: 0.82333
# [1800]	valid_0's auc: 0.823119	valid_0's pr_auc: 0.823296
# [1820]	valid_0's auc: 0.823081	valid_0's pr_auc: 0.823318
# [1840]	valid_0's auc: 0.823099	valid_0's pr_auc: 0.823338
# [1860]	valid_0's auc: 0.823	valid_0's pr_auc: 0.823294
# [1880]	valid_0's auc: 0.822965	valid_0's pr_auc: 0.823383
# [1900]	valid_0's auc: 0.822888	valid_0's pr_auc: 0.823437
# [1920]	valid_0's auc: 0.822789	valid_0's pr_auc: 0.823523
# [1940]	valid_0's auc: 0.822771	valid_0's pr_auc: 0.823561
# [1960]	valid_0's auc: 0.822721	valid_0's pr_auc: 0.823558
# [1980]	valid_0's auc: 0.822724	valid_0's pr_auc: 0.823666
# [2000]	valid_0's auc: 0.822664	valid_0's pr_auc: 0.823619
# ==========================================================
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002779 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8436
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 61
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.402333 -> initscore = -0.395752
# [LightGBM] [Info] Start training from score -0.395752
# [20]	valid_0's auc: 0.784661	valid_0's pr_auc: 0.327267
# [40]	valid_0's auc: 0.784787	valid_0's pr_auc: 0.3275
# [60]	valid_0's auc: 0.78499	valid_0's pr_auc: 0.329343
# [80]	valid_0's auc: 0.787083	valid_0's pr_auc: 0.329706
# [100]	valid_0's auc: 0.789536	valid_0's pr_auc: 0.325857
# [120]	valid_0's auc: 0.793265	valid_0's pr_auc: 0.315441
# [140]	valid_0's auc: 0.796659	valid_0's pr_auc: 0.313624
# [160]	valid_0's auc: 0.799367	valid_0's pr_auc: 0.302754
# [180]	valid_0's auc: 0.800381	valid_0's pr_auc: 0.303324
# [200]	valid_0's auc: 0.800606	valid_0's pr_auc: 0.320272
# [1860]	valid_0's auc: 0.815972	valid_0's pr_auc: 0.36674
# [1880]	valid_0's auc: 0.815911	valid_0's pr_auc: 0.366837
# [1900]	valid_0's auc: 0.815701	valid_0's pr_auc: 0.366644
# [1920]	valid_0's auc: 0.815526	valid_0's pr_auc: 0.367366
# [1940]	valid_0's auc: 0.815393	valid_0's pr_auc: 0.366836
# [1960]	valid_0's auc: 0.815448	valid_0's pr_auc: 0.366706
# [1980]	valid_0's auc: 0.815368	valid_0's pr_auc: 0.366642
# [2000]	valid_0's auc: 0.815173	valid_0's pr_auc: 0.367427
# ==========================================================
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004247 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8545
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 61
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.393167 -> initscore = -0.434021
# [LightGBM] [Info] Start training from score -0.434021
# [20]	valid_0's auc: 0.757403	valid_0's pr_auc: 0.39113
# [40]	valid_0's auc: 0.76209	valid_0's pr_auc: 0.395301
# [60]	valid_0's auc: 0.764749	valid_0's pr_auc: 0.398936
# [80]	valid_0's auc: 0.764526	valid_0's pr_auc: 0.401425
# [100]	valid_0's auc: 0.76426	valid_0's pr_auc: 0.403363
# [120]	valid_0's auc: 0.767395	valid_0's pr_auc: 0.405848
# [140]	valid_0's auc: 0.771122	valid_0's pr_auc: 0.423177
# [160]	valid_0's auc: 0.773523	valid_0's pr_auc: 0.424656
# [180]	valid_0's auc: 0.774569	valid_0's pr_auc: 0.426352
# [200]	valid_0's auc: 0.775626	valid_0's pr_auc: 0.423928
# [220]	valid_0's auc: 0.776228	valid_0's pr_auc: 0.423405
# [240]	valid_0's auc: 0.776803	valid_0's pr_auc: 0.424021
# [260]	valid_0's auc: 0.777006	valid_0's pr_auc: 0.443751
# [280]	valid_0's auc: 0.777692	valid_0's pr_auc: 0.44515
# [300]	valid_0's auc: 0.778033	valid_0's pr_auc: 0.444176
# [320]	valid_0's auc: 0.778028	valid_0's pr_auc: 0.446718
# [340]	valid_0's auc: 0.777966	valid_0's pr_auc: 0.450517
# [360]	valid_0's auc: 0.778362	valid_0's pr_auc: 0.452473
# [380]	valid_0's auc: 0.778339	valid_0's pr_auc: 0.453957
# [400]	valid_0's auc: 0.778647	valid_0's pr_auc: 0.45443
# [420]	valid_0's auc: 0.779137	valid_0's pr_auc: 0.455289
# [440]	valid_0's auc: 0.779514	valid_0's pr_auc: 0.454705
# [460]	valid_0's auc: 0.78036	valid_0's pr_auc: 0.453007
# [480]	valid_0's auc: 0.780974	valid_0's pr_auc: 0.453589
# [500]	valid_0's auc: 0.781189	valid_0's pr_auc: 0.449993
# [520]	valid_0's auc: 0.781717	valid_0's pr_auc: 0.443222
# [540]	valid_0's auc: 0.782641	valid_0's pr_auc: 0.443251
# [560]	valid_0's auc: 0.783015	valid_0's pr_auc: 0.441379
# [1400]	valid_0's auc: 0.787095	valid_0's pr_auc: 0.455181
# [1420]	valid_0's auc: 0.786839	valid_0's pr_auc: 0.454876
# [1440]	valid_0's auc: 0.786756	valid_0's pr_auc: 0.45633
# [1460]	valid_0's auc: 0.786749	valid_0's pr_auc: 0.45593
# [1480]	valid_0's auc: 0.786688	valid_0's pr_auc: 0.456265
# [1500]	valid_0's auc: 0.786503	valid_0's pr_auc: 0.45678
# [1520]	valid_0's auc: 0.786539	valid_0's pr_auc: 0.457065
# [1540]	valid_0's auc: 0.786466	valid_0's pr_auc: 0.45682
# [1560]	valid_0's auc: 0.786601	valid_0's pr_auc: 0.456996
# [1580]	valid_0's auc: 0.786548	valid_0's pr_auc: 0.456256
# [1600]	valid_0's auc: 0.786698	valid_0's pr_auc: 0.457181
# [1620]	valid_0's auc: 0.786718	valid_0's pr_auc: 0.456568
# [1640]	valid_0's auc: 0.786792	valid_0's pr_auc: 0.456974
# [1660]	valid_0's auc: 0.786739	valid_0's pr_auc: 0.457723
# [1680]	valid_0's auc: 0.786732	valid_0's pr_auc: 0.458022
# [1700]	valid_0's auc: 0.786513	valid_0's pr_auc: 0.45787
# [1720]	valid_0's auc: 0.78635	valid_0's pr_auc: 0.457176
# [1740]	valid_0's auc: 0.786404	valid_0's pr_auc: 0.456919
# [1760]	valid_0's auc: 0.786427	valid_0's pr_auc: 0.456738
# [1780]	valid_0's auc: 0.786423	valid_0's pr_auc: 0.456712
# [1800]	valid_0's auc: 0.786289	valid_0's pr_auc: 0.456382
# [1820]	valid_0's auc: 0.786308	valid_0's pr_auc: 0.456321
# [1840]	valid_0's auc: 0.786302	valid_0's pr_auc: 0.456246
# [1860]	valid_0's auc: 0.786586	valid_0's pr_auc: 0.456072
# [1880]	valid_0's auc: 0.786526	valid_0's pr_auc: 0.455378
# [1900]	valid_0's auc: 0.786606	valid_0's pr_auc: 0.455474
# [1920]	valid_0's auc: 0.786919	valid_0's pr_auc: 0.455287
# [1940]	valid_0's auc: 0.786893	valid_0's pr_auc: 0.454366
# [1960]	valid_0's auc: 0.787065	valid_0's pr_auc: 0.454557
# [1980]	valid_0's auc: 0.787051	valid_0's pr_auc: 0.454428
# [2000]	valid_0's auc: 0.787076	valid_0's pr_auc: 0.454815
# ==========================================================
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001804 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8453
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 61
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.378667 -> initscore = -0.495211
# [LightGBM] [Info] Start training from score -0.495211
# [20]	valid_0's auc: 0.811357	valid_0's pr_auc: 0.556503
# [40]	valid_0's auc: 0.814158	valid_0's pr_auc: 0.557168
# [60]	valid_0's auc: 0.814036	valid_0's pr_auc: 0.557751
# [80]	valid_0's auc: 0.814086	valid_0's pr_auc: 0.560156
# [1740]	valid_0's auc: 0.823046	valid_0's pr_auc: 0.56933
# [1760]	valid_0's auc: 0.823099	valid_0's pr_auc: 0.569944
# [1780]	valid_0's auc: 0.823182	valid_0's pr_auc: 0.569953
# [1800]	valid_0's auc: 0.823159	valid_0's pr_auc: 0.570103
# [1820]	valid_0's auc: 0.823201	valid_0's pr_auc: 0.570051
# [1840]	valid_0's auc: 0.823099	valid_0's pr_auc: 0.570516
# [1860]	valid_0's auc: 0.823119	valid_0's pr_auc: 0.570186
# [1880]	valid_0's auc: 0.823229	valid_0's pr_auc: 0.570001
# [1900]	valid_0's auc: 0.823227	valid_0's pr_auc: 0.570028
# [1920]	valid_0's auc: 0.823343	valid_0's pr_auc: 0.569966
# [1940]	valid_0's auc: 0.82332	valid_0's pr_auc: 0.569882
# [1960]	valid_0's auc: 0.823152	valid_0's pr_auc: 0.569633
# [1980]	valid_0's auc: 0.823199	valid_0's pr_auc: 0.569914
# [2000]	valid_0's auc: 0.823224	valid_0's pr_auc: 0.56971
# ==========================================================
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002223 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8218
# [LightGBM] [Info] Number of data points in the train set: 12000, number of used features: 61
# [LightGBM] [Warning] Unknown parameter: linear_tree
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.189750 -> initscore = -1.451635
# [LightGBM] [Info] Start training from score -1.451635
# [20]	valid_0's auc: 0.786767	valid_0's pr_auc: 0.973258
# [40]	valid_0's auc: 0.797084	valid_0's pr_auc: 0.974529
# [60]	valid_0's auc: 0.801928	valid_0's pr_auc: 0.975027
# [80]	valid_0's auc: 0.803258	valid_0's pr_auc: 0.975159
# [100]	valid_0's auc: 0.804469	valid_0's pr_auc: 0.975301
# [120]	valid_0's auc: 0.805396	valid_0's pr_auc: 0.975446
# [140]	valid_0's auc: 0.806334	valid_0's pr_auc: 0.975576
# [160]	valid_0's auc: 0.80759	valid_0's pr_auc: 0.975731
# [180]	valid_0's auc: 0.808459	valid_0's pr_auc: 0.975825
# [200]	valid_0's auc: 0.809319	valid_0's pr_auc: 0.975926
# [220]	valid_0's auc: 0.810052	valid_0's pr_auc: 0.976004
# [240]	valid_0's auc: 0.811045	valid_0's pr_auc: 0.97609
# [260]	valid_0's auc: 0.811386	valid_0's pr_auc: 0.976126
# [280]	valid_0's auc: 0.811983	valid_0's pr_auc: 0.976181
# [300]	valid_0's auc: 0.812414	valid_0's pr_auc: 0.976211
# [320]	valid_0's auc: 0.812877	valid_0's pr_auc: 0.976272
# [340]	valid_0's auc: 0.814545	valid_0's pr_auc: 0.976468
# [360]	valid_0's auc: 0.816246	valid_0's pr_auc: 0.976663
# [380]	valid_0's auc: 0.817523	valid_0's pr_auc: 0.976819
# [400]	valid_0's auc: 0.818241	valid_0's pr_auc: 0.976916
# [420]	valid_0's auc: 0.819017	valid_0's pr_auc: 0.976959
# [1280]	valid_0's auc: 0.823685	valid_0's pr_auc: 0.977138
# [1300]	valid_0's auc: 0.823587	valid_0's pr_auc: 0.977153
# [1320]	valid_0's auc: 0.823601	valid_0's pr_auc: 0.977206
# [1340]	valid_0's auc: 0.823529	valid_0's pr_auc: 0.977203
# [1360]	valid_0's auc: 0.823632	valid_0's pr_auc: 0.977232
# [1380]	valid_0's auc: 0.823772	valid_0's pr_auc: 0.97725
# [1400]	valid_0's auc: 0.823891	valid_0's pr_auc: 0.977258
# [1420]	valid_0's auc: 0.823933	valid_0's pr_auc: 0.977245
# [1440]	valid_0's auc: 0.823955	valid_0's pr_auc: 0.977268
# [1460]	valid_0's auc: 0.823769	valid_0's pr_auc: 0.977259
# [1480]	valid_0's auc: 0.823809	valid_0's pr_auc: 0.977275
# [1500]	valid_0's auc: 0.823757	valid_0's pr_auc: 0.977255
# [1520]	valid_0's auc: 0.823689	valid_0's pr_auc: 0.977234
# [1540]	valid_0's auc: 0.82374	valid_0's pr_auc: 0.977258
# [1560]	valid_0's auc: 0.8237	valid_0's pr_auc: 0.977267
# [1580]	valid_0's auc: 0.823683	valid_0's pr_auc: 0.977272
# [1600]	valid_0's auc: 0.82359	valid_0's pr_auc: 0.977283
# [1620]	valid_0's auc: 0.823631	valid_0's pr_auc: 0.977271
# [1640]	valid_0's auc: 0.82362	valid_0's pr_auc: 0.977264
# [1660]	valid_0's auc: 0.823496	valid_0's pr_auc: 0.977265
# [1680]	valid_0's auc: 0.82353	valid_0's pr_auc: 0.977255
# [1700]	valid_0's auc: 0.823436	valid_0's pr_auc: 0.977237
# [1720]	valid_0's auc: 0.823483	valid_0's pr_auc: 0.977247
# [1740]	valid_0's auc: 0.823464	valid_0's pr_auc: 0.977223
# [1760]	valid_0's auc: 0.823512	valid_0's pr_auc: 0.977192
# [1780]	valid_0's auc: 0.823447	valid_0's pr_auc: 0.977209
# [1800]	valid_0's auc: 0.823445	valid_0's pr_auc: 0.977191
# [1820]	valid_0's auc: 0.823457	valid_0's pr_auc: 0.977207
# [1840]	valid_0's auc: 0.82343	valid_0's pr_auc: 0.977205
# [1860]	valid_0's auc: 0.823517	valid_0's pr_auc: 0.977225
# [1880]	valid_0's auc: 0.823561	valid_0's pr_auc: 0.977226
# [1900]	valid_0's auc: 0.823561	valid_0's pr_auc: 0.977213
# [1920]	valid_0's auc: 0.823426	valid_0's pr_auc: 0.977186
# [1940]	valid_0's auc: 0.823333	valid_0's pr_auc: 0.977161
# [1960]	valid_0's auc: 0.823151	valid_0's pr_auc: 0.977129
# [1980]	valid_0's auc: 0.823164	valid_0's pr_auc: 0.977145
# [2000]	valid_0's auc: 0.823228	valid_0's pr_auc: 0.977164
# ==========================================================

# %% [markdown]
# # 4. 교차검증 점수 확인

# %%
auc_scores
# Out:
# [0.8226635983964601,
#  0.8151726094536363,
#  0.7870755248696633,
#  0.8232235462871014,
#  0.823227991000582]

# %%
print(np.mean(auc_scores))
# Out:
# 0.8142726540014886

# %%
import lightgbm as lgbm

# %%
params = {
    'objective' :'binary',
    'learning_rate' : 0.02,
    'num_leaves' : 76,
    'feature_fraction': 0.64, 
    'bagging_fraction': 0.8, 
    'bagging_freq':1,
    'boosting_type' : 'gbdt',
    'metric': 'binary_logloss'
}

from sklearn.model_selection import train_test_split


for i, j in enumerate(col):
    print('fitting column : '+j)
    # making test - valid sets
    X_train, X_valid, Y_train, Y_valid = train_test_split(countvec_df_train_,  train[j], random_state=7, test_size=0.33)
    
    # making lgbm datasets for train and valid
    d_train = lgbm.Dataset(X_train, Y_train)
    d_valid = lgbm.Dataset(X_valid, Y_valid)
    
    # training with early stop
    bst = lgbm.train(params, d_train, 5000, valid_sets=[d_valid], verbose_eval=50, early_stopping_rounds=100)
    
    # making prediciton for one column
    print('predicting for :' +j)
    preds[:,i] = bst.predict(countvec_df_test_)

print('Fininshed Training')

# %% [markdown]
# # 5. 제출 파일 생성

# %%
test_err  = pd.read_csv(PATH+'test_err_data.csv')
display(test_err.head())
# Out:
#    user_id            time model_nm       fwver  errtype errcode
# 0    30000  20201101030227  model_1  04.16.3553       31       1
# 1    30000  20201101030227  model_1  04.16.3553       33       2
# 2    30000  20201101030228  model_1  04.16.3553       15       1
# 3    30000  20201101030256  model_1  04.16.3553       22       1
# 4    30000  20201101030300  model_1  04.16.3553       11       1

# %%
# 데이터 설명을 확인하면
# test 데이터는 ueser_id가 30000부터 44998까지 총 14999개가 존재.
test_user_id_max = 44998
test_user_id_min = 30000
test_user_number = 14999

# %%
id_error = test_err[['user_id','errtype']].values
test_x = np.zeros((test_user_number,42))
for person_idx, err in tqdm(id_error):
    # person_idx - test_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    test_x[person_idx - test_user_id_min,err - 1] += 1
test_x = test_x.reshape(test_x.shape[0],-1)
print(test_x.shape)
# Out:
# 100%|██████████| 16532648/16532648 [00:40<00:00, 408044.66it/s]
# (14999, 42)

# %%
# 예측
pred_y_list = []
for model in models:
    pred_y = model.predict(test_x)
    pred_y_list.append(pred_y.reshape(-1,1))
    
pred_ensemble = np.mean(pred_y_list, axis = 0)

# %%
pred_ensemble
# Out:
# array([[0.77981028],
#        [0.21930262],
#        [0.29921489],
#        ...,
#        [0.43839372],
#        [0.76868059],
#        [0.35637135]])

# %%
sample_submssion = pd.read_csv(PATH+'sample_submission.csv')

# %%
sample_submssion['problem'] = pred_ensemble.reshape(-1)

# %%
SUB_PATH = '/content/drive/MyDrive/YBIGTA/21-1 겨울방학/lg 품질변화 공모전/quality_change_prediction/submissions/'
sample_submssion.to_csv(SUB_PATH+"dacon_baseline_0111(1).csv", index = False)
sample_submssion
# Out:
#        user_id   problem
# 0        30000  0.779810
# 1        30001  0.219303
# 2        30002  0.299215
# 3        30003  0.648380
# 4        30004  0.578343
# ...        ...       ...
# 14994    44994  0.330235
# 14995    44995  0.311575
# 14996    44996  0.438394
# 14997    44997  0.768681
# 14998    44998  0.356371
#
# [14999 rows x 2 columns]
